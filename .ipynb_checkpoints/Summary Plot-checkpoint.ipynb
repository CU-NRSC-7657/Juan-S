# %%
import os
import pandas as pd
from tqdm import tqdm
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl
import seaborn as sns
from dlab.sglx_analysis import readMeta
from dlab import sorting_quality as sq
from matplotlib.gridspec import GridSpec
from dlab import summary_plots as summary

# %%
images = r'C:\Users\juans\Pictures\Wallpapers'

# %%
def summary_plot(img_path, num_rfs):
#     images = glob(img_path+'\*.svg')
    images = glob(img_path+'\*.jpg')
    receptive_fields = images[1:1+num_rfs]
    gratings = [1+num_rfs]
    
    fig = plt.figure(figsize=(15,10))
    gs = GridSpec(10,10)
    plt.rcParams.update({'axes.spines.top': False, 'axes.spines.right': False, 'axes.spines.bottom': False, 
                         'axes.spines.left':False, 'xtick.bottom':False, 'ytick.left':False,'xtick.labelbottom':False,
                         'ytick.labelleft':False})
    
    ax1 = fig.add_subplot(gs[])
    plt.imshow(plt.imread(images[0]))
    
    ax2 = fig.add_subplot(gs[1,:])
    plt.imshow(plt.imread(images[1]))

# %%
summary_plot(img_path=images,num_rfs=3)
